# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
from matplotlib import rcParams
from scipy.optimize import curve_fit
from cycler import cycler
import matplotlib as mpl

# %%
plt.rcdefaults()

# axes
rcParams['axes.grid'] = True
rcParams['axes.grid.axis'] = 'both'
rcParams['axes.axisbelow'] = True
rcParams['axes.prop_cycle'] = cycler('color', ['teal', 'firebrick', 'darkgoldenrod', 'navy', 'olive', 'darkorchid', 'slategray', 'mediumvioletred', 'saddlebrown', 'black'])

# figure:
rcParams['figure.autolayout'] = True
rcParams['figure.dpi'] = 100
rcParams['figure.figsize'] = [7.4, 4.8]


# fontsizes
rcParams['xtick.labelsize'] = 12
rcParams['ytick.labelsize'] = 12
rcParams['legend.fontsize'] = 12
rcParams['legend.title_fontsize'] = 12
rcParams['axes.labelsize'] = 16
# rcParams['axes.title.size'] = 16

rcParams['font.family'] = 'serif'
rcParams['mathtext.fontset'] = 'dejavuserif'

# legend
# rcParams['legend.framealpha'] = 1
rcParams['legend.fancybox'] = False
rcParams['legend.edgecolor'] = 'gray'


# save
rcParams['savefig.bbox'] = 'tight'

# %%
centro_1 = np.array([])
centro_1x = np.array([])
centro_1y = np.array([]) 

centro_2 = np.array([])
centro_2x = np.array([])
centro_2y = np.array([])

for i in range(1, 10):
    data = pd.read_csv(f'Mediciones/2 vortices tapados sentido contrario clase4/2 vortices tapados sentido contrario clase4_000{i}.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
    x, y, u, v, tipo, vort, m, d, e, f, g, h = np.array(data['x'])*100, np.array(data['y'])*100, np.array(data['u'])*100, np.array(data['v'])*100, np.array(data['tipo']), np.array(data['vorticidad']), np.array(data['m']), np.array(data['d']), np.array(data['e']), np.array(data['f']), np.array(data['g']), np.array(data['h'])

    maximo = np.max(vort[vort>0])
    centro_1 = np.append(centro_1, maximo)
    
    x_maximo = x[np.nonzero(vort == maximo)]
    y_maximo = y[np.nonzero(vort == maximo)]
    centro_1x = np.append(centro_1x, x_maximo)
    centro_1y = np.append(centro_1y, y_maximo)

    minimo = np.min(vort[vort<0])
    centro_2 = np.append(centro_2, minimo)

    x_minimo = x[np.nonzero(vort == minimo)]
    y_minimo = y[np.nonzero(vort == minimo)]
    centro_2x = np.append(centro_2x, x_minimo)
    centro_2y = np.append(centro_2y, y_minimo)


for i in range(10, 37):
    data = pd.read_csv(f'Mediciones/2 vortices tapados sentido contrario clase4/2 vortices tapados sentido contrario clase4_00{i}.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
    x, y, u, v, tipo, vort, m, d, e, f, g, h = np.array(data['x'])*100, np.array(data['y'])*100, np.array(data['u'])*100, np.array(data['v'])*100, np.array(data['tipo']), np.array(data['vorticidad']), np.array(data['m']), np.array(data['d']), np.array(data['e']), np.array(data['f']), np.array(data['g']), np.array(data['h'])

    maximo = np.max(vort[vort>0])
    centro_1 = np.append(centro_1, maximo)
    
    x_maximo = x[np.nonzero(vort == maximo)]
    y_maximo = y[np.nonzero(vort == maximo)]
    centro_1x = np.append(centro_1x, x_maximo)
    centro_1y = np.append(centro_1y, y_maximo)

    minimo = np.min(vort[vort<0])
    centro_2 = np.append(centro_2, minimo)

    x_minimo = x[np.nonzero(vort == minimo)]
    y_minimo = y[np.nonzero(vort == minimo)]
    centro_2x = np.append(centro_2x, x_minimo)
    centro_2y = np.append(centro_2y, y_minimo)

tiempo = np.arange(0, 36)/30

# %%
data1 = pd.read_csv(f'Mediciones/2 vortices tapados sentido contrario clase4/2 vortices tapados sentido contrario clase4_0003.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
x1, y1, u1, v1, tipo, vort1, m, d, e, f, g, h = np.array(data1['x'])*100, np.array(data1['y'])*100, np.array(data1['u'])*100, np.array(data1['v'])*100, np.array(data1['tipo']), np.array(data1['vorticidad']), np.array(data1['m']), np.array(data1['d']), np.array(data1['e']), np.array(data1['f']), np.array(data1['g']), np.array(data1['h'])

data36 = pd.read_csv(f'Mediciones/2 vortices tapados sentido contrario clase4/2 vortices tapados sentido contrario clase4_0036.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
x36, y36, u36, v36, tipo, vort36, m, d, e, f, g, h = np.array(data36['x'])*100, np.array(data36['y'])*100, np.array(data36['u'])*100, np.array(data36['v'])*100, np.array(data36['tipo']), np.array(data36['vorticidad']), np.array(data36['m']), np.array(data36['d']), np.array(data36['e']), np.array(data36['f']), np.array(data36['g']), np.array(data36['h'])

mapa = mpl.cm.get_cmap('plasma')

fig1, (ax1, ax2) = plt.subplots(1, 2, figsize = (8, 4))
# ax1.grid(color='white')
ax1.set_facecolor('aliceblue')
ax1.quiver(x1, y1, u1, v1, vort1, cmap=mapa)
ax1.set_title(f't = {3/30} s')
ax1.plot(centro_1x[2], centro_1y[2], '.', color=mapa(1.0))
ax1.plot(centro_2x[2], centro_2y[2], '.', color=mapa(0.0))
ax1.plot([centro_1x[2], centro_2x[2]], [centro_1y[2], centro_2y[2]], linestyle='dashed', color='g')
ax1.set_xlim(12.5, ax1.get_xlim()[1])
ax1.set_ylim(19, 31)
ax1.set_xlabel('x')
ax1.set_ylabel('y')


ax2.set_facecolor('aliceblue')
ax2.quiver(x36, y36, u36, v36, vort36, cmap='plasma')
ax2.plot(centro_1x[-1], centro_1y[-1], '.', color=mapa(1.0))
ax2.plot(centro_2x[-1], centro_2y[-1], '.', color=mapa(0.0))
ax2.plot([centro_1x[-1], centro_2x[-1]], [centro_1y[-1], centro_2y[-1]], linestyle='dashed', color='g')
ax2.set_title(f't = {36/30} s')
ax2.set_xlabel('x')
ax2.set_xlim(12.5, ax1.get_xlim()[1])
ax2.set_ylim(19, 31)

# fig2, (ax3, ax4) = plt.subplots(2, 1, figsize = (8, 4))
# ax3.plot(tiempo, centro_1x)
# ax4.plot(tiempo, centro_1y)
# Out:
# C:\Users\pauli\AppData\Local\Temp\ipykernel_3924\1012184314.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   mapa = mpl.cm.get_cmap('plasma')
# (19.0, 31.0)

# %%
centro_1 = np.array([])
centro_1x = np.array([])
centro_1y = np.array([]) 

centro_2 = np.array([])
centro_2x = np.array([])
centro_2y = np.array([])

for i in range(1, 10):
    data = pd.read_csv(f'Mediciones/2 vortices tapados mismo sentido clase4/2 vortices tapados mismo sentido clase 4_000{i}.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
    x, y, u, v, tipo, vort, m, d, e, f, g, h = np.array(data['x'])*100, np.array(data['y'])*100, np.array(data['u'])*100, np.array(data['v'])*100, np.array(data['tipo']), np.array(data['vorticidad']), np.array(data['m']), np.array(data['d']), np.array(data['e']), np.array(data['f']), np.array(data['g']), np.array(data['h'])

    min1 = np.min(vort[y>30])
    centro_1 = np.append(centro_1, min1)
    
    x_min1 = x[np.nonzero(vort == min1)[0][0]]
    y_min1 = y[np.nonzero(vort == min1)[0][0]]
    centro_1x = np.append(centro_1x, x_min1)
    centro_1y = np.append(centro_1y, y_min1)

    min2 = np.min(vort[y<30])
    centro_2 = np.append(centro_2, min2)

    x_min2 = x[np.nonzero(vort == min2)]
    y_min2 = y[np.nonzero(vort == min2)]
    centro_2x = np.append(centro_2x, x_min2)
    centro_2y = np.append(centro_2y, y_min2)


for i in range(10, 82):
    data = pd.read_csv(f'Mediciones/2 vortices tapados mismo sentido clase4/2 vortices tapados mismo sentido clase 4_00{i}.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
    x, y, u, v, tipo, vort, m, d, e, f, g, h = np.array(data['x'])*100, np.array(data['y'])*100, np.array(data['u'])*100, np.array(data['v'])*100, np.array(data['tipo']), np.array(data['vorticidad']), np.array(data['m']), np.array(data['d']), np.array(data['e']), np.array(data['f']), np.array(data['g']), np.array(data['h'])

    min1 = np.min(vort[y>30])
    centro_1 = np.append(centro_1, min1)
    
    x_min1 = x[np.nonzero(vort == min1)[0][0]]
    y_min1 = y[np.nonzero(vort == min1)[0][0]]
    centro_1x = np.append(centro_1x, x_min1)
    centro_1y = np.append(centro_1y, y_min1)



    min2 = np.min(vort[y<30])
    centro_2 = np.append(centro_2, min2)

    x_min2 = x[np.nonzero(vort == min2)]
    y_min2 = y[np.nonzero(vort == min2)]
    centro_2x = np.append(centro_2x, x_min2)
    centro_2y = np.append(centro_2y, y_min2)

tiempo = np.arange(0, 82)/30

# %%
data1 = pd.read_csv(f'Mediciones/2 vortices tapados mismo sentido clase4/2 vortices tapados mismo sentido clase 4_0001.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
x1, y1, u1, v1, tipo, vort1, m, d, e, f, g, h = np.array(data1['x'])*100, np.array(data1['y'])*100, np.array(data1['u'])*100, np.array(data1['v'])*100, np.array(data1['tipo']), np.array(data1['vorticidad']), np.array(data1['m']), np.array(data1['d']), np.array(data1['e']), np.array(data1['f']), np.array(data1['g']), np.array(data1['h'])

data36 = pd.read_csv(f'Mediciones/2 vortices tapados mismo sentido clase4/2 vortices tapados mismo sentido clase 4_0057.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
x36, y36, u36, v36, tipo, vort36, m, d, e, f, g, h = np.array(data36['x'])*100, np.array(data36['y'])*100, np.array(data36['u'])*100, np.array(data36['v'])*100, np.array(data36['tipo']), np.array(data36['vorticidad']), np.array(data36['m']), np.array(data36['d']), np.array(data36['e']), np.array(data36['f']), np.array(data36['g']), np.array(data36['h'])

data81 = pd.read_csv(f'Mediciones/2 vortices tapados mismo sentido clase4/2 vortices tapados mismo sentido clase 4_0081.txt', header = 0, names = ['x','y','u','v','tipo','vorticidad','m','d','e','f','g','h'], dtype = {'x': np.float64, 'y': np.float64, 'u': np.float64, 'v': np.float64, 'tipo': np.int32, 'vorticidad': np.float64, 'm': np.float64, 'd': np.float64, 'e': np.float64, 'f': np.float64, 'g': np.float64, 'h': np.float64}, skiprows=2)
x81, y81, u81, v81, tipo, vort81, m, d, e, f, g, h = np.array(data81['x'])*100, np.array(data81['y'])*100, np.array(data81['u'])*100, np.array(data81['v'])*100, np.array(data36['tipo']), np.array(data81['vorticidad']), np.array(data36['m']), np.array(data36['d']), np.array(data36['e']), np.array(data36['f']), np.array(data36['g']), np.array(data81['h'])
mapa = mpl.cm.get_cmap('plasma')

fig1, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (8, 4))
# ax1.grid(color='white')
ax1.set_facecolor('aliceblue')
ax1.quiver(x1, y1, u1, v1, vort1, cmap=mapa)
ax1.set_title(f't = {0/30} s')
ax1.plot(centro_1x[0], centro_1y[0], '.', color=mapa(0.0))
ax1.plot(centro_2x[0], centro_2y[0], '.', color=mapa(0.0))
ax1.plot([centro_1x[0], centro_2x[0]], [centro_1y[0], centro_2y[0]], linestyle='dashed', color='g')
ax1.set_xlabel('x')
ax1.set_ylabel('y')


ax2.set_facecolor('aliceblue')
ax2.quiver(x36, y36, u36, v36, vort36, cmap='plasma')
ax2.plot(centro_1x[56], centro_1y[56], '.', color=mapa(0.0))
ax2.plot(centro_2x[56], centro_2y[56], '.', color=mapa(0.0))
ax2.plot([centro_1x[56], centro_2x[56]], [centro_1y[56], centro_2y[56]], linestyle='dashed', color='g')
ax2.set_title(f't = {round(56/30, 2)} s')
ax2.set_xlabel('x')

ax3.set_facecolor('aliceblue')
ax3.quiver(x81, y81, u81, v81, vort81, cmap='plasma')
ax3.plot(centro_1x[80], centro_1y[80], '.', color=mapa(0.0))
ax3.plot(centro_2x[80], centro_2y[80], '.', color=mapa(0.0))
ax3.plot([centro_1x[80], centro_2x[80]], [centro_1y[80], centro_2y[80]], linestyle='dashed', color='g')
ax3.set_title(f't = {round(80/30, 2)} s')
ax3.set_xlabel('x')
# Out:
# C:\Users\pauli\AppData\Local\Temp\ipykernel_3924\3552765014.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   mapa = mpl.cm.get_cmap('plasma')
# Text(0.5, 0, 'x')
